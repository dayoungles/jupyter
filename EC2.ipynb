# %% [markdown]
# # EC2 CLI Actions

# %%
# !aws ec2 describe-instances
# Out:
# {
#     "Reservations": [
#         {
#             "Groups": [],
#             "Instances": [
#                 {
#                     "AmiLaunchIndex": 0,
#                     "ImageId": "ami-0a10b2721688ce9d2",
#                     "InstanceId": "i-099c92f42f83d846a",
#                     "InstanceType": "t2.micro",
#                     "KeyName": "important_keypair",
#                     "LaunchTime": "2018-10-29T14:21:23+00:00",
#                     "Monitoring": {
#                         "State": "disabled"
#                     },
#                     "Placement": {
#                         "AvailabilityZone": "ap-northeast-2a",
#                         "GroupName": "",
#                         "Tenancy": "default"
#                     },
#                     "PrivateDnsName": "ip-172-31-12-135.ap-northeast-2.compute.internal",
#                     "PrivateIpAddress": "172.31.12.135",
#                     "ProductCodes": [],
# ...
